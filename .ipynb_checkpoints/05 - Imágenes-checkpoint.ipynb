# %%
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
type(mapache)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt # Hacer gráficos

# %%
plt.imshow(mapache)
#plt.show(mapache)

# %%
plt.imshow(mapache[::-1])

# %%
arr1, arr2 = np.split(mapache,2)
plt.imshow(arr1)
plt.show()
plt.imshow(arr2)
plt.show()

# %%
# Tener la foto del mapache en escala de grises
def escala_grises(imagen):
  filtro = []
  for i in imagen:
      for r,g,b in i:
          rojo = r*0.2989
          verde = g*0.5870
          azul = b*0.1140
          numero = [int(rojo + verde + azul)]
          filtro.append(numero)
  result = np.reshape(filtro, imagen.shape[:2])
  return result

def muestra_imagen(imagen, cmap="Greys_r"):
    plt.imshow(imagen, cmap=cmap)
    plt.show()

muestra_imagen(escala_grises(mapache))

# %%
# Dividir el mapache en 4 partes iguales
def partes_4(imagen):
    arr1, arr2 = np.split(mapache,2)
    arr1, arr3 = np.hsplit(arr1,2)
    arr2, arr4 = np.hsplit(arr2,2)
    plt.imshow(arr1)
    plt.show()
    plt.imshow(arr3)
    plt.show()
    plt.imshow(arr2)
    plt.show()
    plt.imshow(arr4)
    plt.show()
    
partes_4(mapache)

# %%
def zoom (imagen)
    data=np.arange(9).reshape((3,3))
    plt.imshow(data)
    plt.xlim(0.5, 1.5)
    plt.ylim(0.5,1.5)
    plt.show()
    
zoom(mapache)
# Out:
#   File "<ipython-input-76-92d9e673af49>", line 1
#     def zoom (imagen)
#                      ^
# SyntaxError: invalid syntax
